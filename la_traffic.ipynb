# %%
# import libaries
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
# import data. data is in a zipfile
import zipfile
with zipfile.ZipFile('los-angeles-traffic-collision-data.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
la_df = pd.read_csv('traffic-collision-data-from-2010-to-present.csv')

# %% [markdown]
# ### Just a note, you can access the docstring of any function, method, variable (pretty much anything) by adding '?' after a comand. Example:
# - md_df.head?
# - md_df?
# - pd.read_csv?

# %%
la_df.head()
# Out:
#    DR Number            Date Reported            Date Occurred  Time Occurred  \
# 0  190316163  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1215
# 1  192112389  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000            830
# 2  190614945  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1240
# 3  191415527  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1350
# 4  191011897  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1105
#
#    Area ID    Area Name  Reporting District  Crime Code  \
# 0        3    Southwest                 351         997
# 1       21      Topanga                2157         997
# 2        6    Hollywood                 643         997
# 3       14      Pacific                1457         997
# 4       10  West Valley                1025         997
#
#   Crime Code Description MO Codes                ...                  \
# 0      TRAFFIC COLLISION      NaN                ...
# 1      TRAFFIC COLLISION      NaN                ...
# 2      TRAFFIC COLLISION      NaN                ...
# 3      TRAFFIC COLLISION     1402                ...
# 4      TRAFFIC COLLISION      NaN                ...
#
#    Premise Description                                   Address  \
# 0               STREET           EXPOSITION                   BL
# 1               STREET                                   DE SOTO
# 2               STREET           FRANKLIN                     AV
# 3               STREET  12300    CULVER                       BL
# 4               STREET           SHERMAN                      WY
#
#                       Cross Street  \
# 0  LA BREA                      AV
# 1                        KITTRIDGE
# 2  FULLER                       AV
# 3                              NaN
# 4  LINDLEY                      AV
#
#                                             Location Zip Codes Census Tracts  \
# 0  {'latitude': '34.025', 'human_address': '{"add...   23077.0         669.0
# 1  {'latitude': '34.1938', 'human_address': '{"ad...    4282.0         294.0
# 2  {'latitude': '34.1035', 'human_address': '{"ad...   23677.0         456.0
# 3  {'latitude': '33.992', 'human_address': '{"add...   24031.0         918.0
# 4  {'latitude': '34.2011', 'human_address': '{"ad...   18909.0         258.0
#
#   Precinct Boundaries LA Specific Plans  Council Districts  \
# 0               986.0               NaN               12.0
# 1              1547.0               2.0                4.0
# 2               904.0               NaN                7.0
# 3              1137.0              10.0               10.0
# 4               284.0               NaN                4.0
#
#    Neighborhood Councils (Certified)
# 0                               17.0
# 1                               66.0
# 2                               82.0
# 3                               85.0
# 4                               12.0
#
# [5 rows x 24 columns]

# %%
la_df.set_index('DR Number', inplace=True)

# %%
la_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 479425 entries, 190316163 to 111904006
# Data columns (total 23 columns):
# Date Reported                        479425 non-null object
# Date Occurred                        479425 non-null object
# Time Occurred                        479425 non-null int64
# Area ID                              479425 non-null int64
# Area Name                            479425 non-null object
# Reporting District                   479425 non-null int64
# Crime Code                           479425 non-null int64
# Crime Code Description               479425 non-null object
# MO Codes                             394280 non-null object
# Victim Age                           401954 non-null float64
# Victim Sex                           472433 non-null object
# Victim Descent                       471712 non-null object
# Premise Code                         479400 non-null float64
# Premise Description                  479400 non-null object
# Address                              479425 non-null object
# Cross Street                         458063 non-null object
# Location                             479425 non-null object
# Zip Codes                            479028 non-null float64
# Census Tracts                        472928 non-null float64
# Precinct Boundaries                  476348 non-null float64
# LA Specific Plans                    176418 non-null float64
# Council Districts                    473732 non-null float64
# Neighborhood Councils (Certified)    455451 non-null float64
# dtypes: float64(8), int64(4), object(11)
# memory usage: 87.8+ MB

# %%
la_df.head(1)
# Out:
#                      Date Reported            Date Occurred  Time Occurred  \
# DR Number
# 190316163  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1215
#
#            Area ID  Area Name  Reporting District  Crime Code  \
# DR Number
# 190316163        3  Southwest                 351         997
#
#           Crime Code Description MO Codes  Victim Age  \
# DR Number
# 190316163      TRAFFIC COLLISION      NaN        46.0
#
#                          ...                 Premise Description  \
# DR Number                ...
# 190316163                ...                              STREET
#
#                                    Address                     Cross Street  \
# DR Number
# 190316163  EXPOSITION                   BL  LA BREA                      AV
#
#                                                     Location Zip Codes  \
# DR Number
# 190316163  {'latitude': '34.025', 'human_address': '{"add...   23077.0
#
#           Census Tracts Precinct Boundaries  LA Specific Plans  \
# DR Number
# 190316163         669.0               986.0                NaN
#
#            Council Districts  Neighborhood Councils (Certified)
# DR Number
# 190316163               12.0                               17.0
#
# [1 rows x 23 columns]

# %%
# to only view specific columns, use this formate df[['name', 'name2']].head()
la_df[['Area Name', 'Crime Code', 'Victim Age']].head()
# Out:
#              Area Name  Crime Code  Victim Age
# DR Number
# 190316163    Southwest         997        46.0
# 192112389      Topanga         997        32.0
# 190614945    Hollywood         997        29.0
# 191415527      Pacific         997         NaN
# 191011897  West Valley         997        45.0

# %% [markdown]
# You can index the rows by using the loc and iloc accessors.
#
# - loc does label-based indexing
# - iloc performs integer-based indexing
#
# You can use a comma separated list to access multiple fields at the same time.
# Both support the standard Python slicing operations [start:end:step]

# %%
la_df.loc[190316163]
# Out:
# Date Reported                                                  2019-07-06T00:00:00.000
# Date Occurred                                                  2019-07-06T00:00:00.000
# Time Occurred                                                                     1215
# Area ID                                                                              3
# Area Name                                                                    Southwest
# Reporting District                                                                 351
# Crime Code                                                                         997
# Crime Code Description                                               TRAFFIC COLLISION
# MO Codes                                                                           NaN
# Victim Age                                                                          46
# Victim Sex                                                                           F
# Victim Descent                                                                       H
# Premise Code                                                                       101
# Premise Description                                                             STREET
# Address                                                EXPOSITION                   BL
# Cross Street                                           LA BREA                      AV
# Location                             {'latitude': '34.025', 'human_address': '{"add...
# Zip Codes                                                                        23077
# Census Tracts                                                                      669
# Precinct Boundaries                                                                986
# LA Specific Plans                                                                  NaN
# Council Districts                                                                   12
# Neighborhood Councils (Certified)                                                   17
# Name: 190316163, dtype: object

# %%
# use double brackets for two or more, df.loc[[index, index2]]
la_df.loc[[190316163, 191011897]]
# Out:
#                      Date Reported            Date Occurred  Time Occurred  \
# DR Number
# 190316163  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1215
# 191011897  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1105
#
#            Area ID    Area Name  Reporting District  Crime Code  \
# DR Number
# 190316163        3    Southwest                 351         997
# 191011897       10  West Valley                1025         997
#
#           Crime Code Description MO Codes  Victim Age  \
# DR Number
# 190316163      TRAFFIC COLLISION      NaN        46.0
# 191011897      TRAFFIC COLLISION      NaN        45.0
#
#                          ...                 Premise Description  \
# DR Number                ...
# 190316163                ...                              STREET
# 191011897                ...                              STREET
#
#                                    Address                     Cross Street  \
# DR Number
# 190316163  EXPOSITION                   BL  LA BREA                      AV
# 191011897  SHERMAN                      WY  LINDLEY                      AV
#
#                                                     Location Zip Codes  \
# DR Number
# 190316163  {'latitude': '34.025', 'human_address': '{"add...   23077.0
# 191011897  {'latitude': '34.2011', 'human_address': '{"ad...   18909.0
#
#           Census Tracts Precinct Boundaries  LA Specific Plans  \
# DR Number
# 190316163         669.0               986.0                NaN
# 191011897         258.0               284.0                NaN
#
#            Council Districts  Neighborhood Councils (Certified)
# DR Number
# 190316163               12.0                               17.0
# 191011897                4.0                               12.0
#
# [2 rows x 23 columns]

# %%
# iloc searching by interger based. Meaning 0, 1, 2,... seaching the 1st row, 2nd row, etc
la_df.iloc[1]

#get every 5th row starting from 10, until 25.
la_df.iloc[10:25:5]
# Out:
#                      Date Reported            Date Occurred  Time Occurred  \
# DR Number
# 191011898  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1130
# 190411883  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000            950
# 192112342  2019-07-05T00:00:00.000  2019-07-05T00:00:00.000           1035
#
#            Area ID    Area Name  Reporting District  Crime Code  \
# DR Number
# 191011898       10  West Valley                1028         997
# 190411883        4   Hollenbeck                 423         997
# 192112342       21      Topanga                2156         997
#
#           Crime Code Description MO Codes  Victim Age  \
# DR Number
# 191011898      TRAFFIC COLLISION      NaN        25.0
# 190411883      TRAFFIC COLLISION      NaN        60.0
# 192112342      TRAFFIC COLLISION      NaN        45.0
#
#                          ...                 Premise Description  \
# DR Number                ...
# 191011898                ...                              STREET
# 190411883                ...                              STREET
# 192112342                ...                              STREET
#
#                                    Address                     Cross Street  \
# DR Number
# 191011898  SHERMAN                      WY  FORBES                       AV
# 190411883                             MAIN                         JOHNSTON
# 192112342  OWENSMOUTH                   AV  VICTORY                      BL
#
#                                                     Location Zip Codes  \
# DR Number
# 191011898  {'latitude': '34.2012', 'human_address': '{"ad...   19734.0
# 190411883  {'latitude': '34.066', 'human_address': '{"add...   23448.0
# 192112342  {'latitude': '34.1878', 'human_address': '{"ad...    4278.0
#
#           Census Tracts Precinct Boundaries  LA Specific Plans  \
# DR Number
# 191011898         263.0               436.0                NaN
# 190411883         494.0               619.0                NaN
# 192112342         299.0               434.0                2.0
#
#            Council Districts  Neighborhood Councils (Certified)
# DR Number
# 191011898                3.0                               61.0
# 190411883               11.0                                1.0
# 192112342                4.0                               49.0
#
# [3 rows x 23 columns]

# %%
# show the first 5 rows and the first 5 columns
la_df.iloc[:5, :5]
# Out:
#                      Date Reported            Date Occurred  Time Occurred  \
# DR Number
# 190316163  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1215
# 192112389  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000            830
# 190614945  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1240
# 191415527  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1350
# 191011897  2019-07-06T00:00:00.000  2019-07-06T00:00:00.000           1105
#
#            Area ID    Area Name
# DR Number
# 190316163        3    Southwest
# 192112389       21      Topanga
# 190614945        6    Hollywood
# 191415527       14      Pacific
# 191011897       10  West Valley

# %%
# show the all the rows up to index 190614945 and the columns named 'Crime Code' and 'Victim Age'
la_df.loc[:190614945, ['Crime Code', 'Victim Age']]
# Out:
#            Crime Code  Victim Age
# DR Number
# 190316163         997        46.0
# 192112389         997        32.0
# 190614945         997        29.0
